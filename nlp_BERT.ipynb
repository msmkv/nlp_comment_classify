# %% [markdown]
# # Проект для «Викишоп» c BERT

# %% [markdown]
# Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# Необходимо обучить модель классифицировать комментарии на позитивные и негативные.

# %% [markdown]
# ## Подготовка

# %%
# !pip install ydata_profiling nltk lightgbm torch transformers tqdm -q

# %%
import os
import pandas as pd
import numpy as np
import ydata_profiling
import seaborn as sns
import matplotlib.pyplot as plt

import nltk
import re
from nltk.corpus import wordnet
from nltk.corpus import stopwords
nltk.download("stopwords") # поддерживает удаление стоп-слов
nltk.download('punkt') # делит текст на список предложений
nltk.download('wordnet') # проводит лемматизацию
stopwords = list(stopwords.words('english'))
nltk.download('averaged_perceptron_tagger')

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

import torch
import transformers as tf
from tqdm import notebook

import pickle
import time

import resource, sys
resource.setrlimit(resource.RLIMIT_STACK, (resource.RLIM_INFINITY, resource.RLIM_INFINITY))
sys.setrecursionlimit(10**6)

RANDOM_STATE = 42
CROSSVAL = 5
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
try:
    data = pd.read_csv('toxic_comments.csv', index_col='Unnamed: 0')
except:
    data = pd.read_csv('https://****.csv', index_col='Unnamed: 0')

# %%
data.head(20)
# Out:
#                                                  text  toxic
# 0   Explanation\nWhy the edits made under my usern...      0
# 1   D'aww! He matches this background colour I'm s...      0
# 2   Hey man, I'm really not trying to edit war. It...      0
# 3   "\nMore\nI can't make any real suggestions on ...      0
# 4   You, sir, are my hero. Any chance you remember...      0
# 5   "\n\nCongratulations from me as well, use the ...      0
# 6        COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK      1
# 7   Your vandalism to the Matt Shirvington article...      0
# 8   Sorry if the word 'nonsense' was offensive to ...      0
# 9   alignment on this subject and which are contra...      0
# 10  "\nFair use rationale for Image:Wonju.jpg\n\nT...      0
# 11  bbq \n\nbe a man and lets discuss it-maybe ove...      0
# 12  Hey... what is it..\n@ | talk .\nWhat is it......      1
# 13  Before you start throwing accusations and warn...      0
# 14  Oh, and the girl above started her arguments w...      0
# 15  "\n\nJuelz Santanas Age\n\nIn 2002, Juelz Sant...      0
# 16  Bye! \n\nDon't look, come or think of comming ...      1
# 17   REDIRECT Talk:Voydan Pop Georgiev- Chernodrinski      0
# 18  The Mitsurugi point made no sense - why not ar...      0
# 19  Don't mean to bother you \n\nI see that you're...      0

# %%
data.profile_report()

# %% [markdown]
# 159292 комментария, пропусков нет, дубликатов нет, есть комментарии разной длины
#
# Очень сильный дисбаланс классов, который будет влиять на метрику, нужно устранять

# %% [markdown]
# ## Обучение

# %% [markdown]
# Очистка и лемматизация текста

# %%
# Lemmatize with POS Tag

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# # 1. Init Lemmatizer
# lemmatizer = WordNetLemmatizer()
# # 2. Lemmatize Single Word with the appropriate POS tag
# word = 'feet'
# print(lemmatizer.lemmatize(word, get_wordnet_pos(word)))
# # 3. Lemmatize a Sentence with the appropriate POS tag
# sentence = "The striped bats are hanging on their feet for best"
# print([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(sentence)])
# #> ['The', 'strip', 'bat', 'be', 'hang', 'on', 'their', 'foot', 'for', 'best']

# %%
# %%time

lemmatizer = nltk.WordNetLemmatizer()

def cleaning(row):
    # удаление+нижний регистр
    text = re.sub('[^a-zA-Z]', ' ', row.text).lower()
    # токенизация
    text = nltk.word_tokenize(text, language = 'english')
    # лемматизация
    text = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text] 
    # соединение слов
    row['text_new'] = ' '.join(text) 
    return row

clean_data = data.apply(cleaning, axis=1).drop(['text'],axis = 1)
# Out:
# CPU times: user 19min 44s, sys: 1min 41s, total: 21min 25s
# Wall time: 21min 26s

# %%
clean_data
# Out:
#         toxic                                           text_new
# 0           0  explanation why the edits make under my userna...
# 1           0  d aww he match this background colour i m seem...
# 2           0  hey man i m really not try to edit war it s ju...
# 3           0  more i can t make any real suggestion on impro...
# 4           0  you sir be my hero any chance you remember wha...
# ...       ...                                                ...
# 159446      0  and for the second time of ask when your view ...
# 159447      0  you should be ashamed of yourself that be a ho...
# 159448      0  spitzer umm there no actual article for prosti...
# 159449      0  and it look like it be actually you who put on...
# 159450      0  and i really don t think you understand i come...
#
# [159292 rows x 2 columns]

# %% [markdown]
# Выделение выборок + TFIDF

# %%
x_train, x_test , y_train, y_test = train_test_split(
    clean_data['text_new'],
    clean_data['toxic'],
    test_size = 0.3,
    random_state = RANDOM_STATE)

# %%
count_tf_idf = TfidfVectorizer(stop_words = stopwords)

# %%
# %%time
tf_idf_x_train = count_tf_idf.fit_transform(x_train)
# Out:
# CPU times: user 4.51 s, sys: 56.2 ms, total: 4.57 s
# Wall time: 4.57 s

# %% [markdown]
# Ребалансировка классов

# %%
class_ratio = data['toxic'].value_counts()[0] / data['toxic'].value_counts()[1]
class_ratio
# Out:
# 8.841344371679229

# %%
# %%time
classificator = LogisticRegression()
train_f1 = cross_val_score(classificator, 
                      tf_idf_x_train, 
                      y_train, 
                      cv=CROSSVAL, 
                      scoring='f1').mean()
print('F1 на CV', train_f1)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# F1 на CV 0.7112140481801166
# CPU times: user 1min 53s, sys: 1min 54s, total: 3min 47s
# Wall time: 3min 48s
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
dict_classes={0:1, 1:class_ratio}

classificator = LogisticRegression(class_weight=dict_classes)

train_f1_balanced = cross_val_score(classificator, 
                                    tf_idf_x_train, 
                                    y_train, 
                                    cv=CROSSVAL, 
                                    scoring='f1').mean()
print('F1 на CV с балансированными классами', train_f1_balanced)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# F1 на CV с балансированными классами 0.7493947756056886
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### LogisticRegression

# %%
modelLR = LogisticRegression(solver = 'lbfgs',
                             max_iter = 1000,
                             class_weight='balanced')

# %%
# %%time
LR = modelLR.fit(tf_idf_x_train, y_train)
# Out:
# CPU times: user 27.3 s, sys: 27.9 s, total: 55.2 s
# Wall time: 55.2 s

# %%
LR_score = cross_val_score(LR, tf_idf_x_train, y_train, cv=CROSSVAL,scoring='f1')
LR_score.mean()
# Out:
# 0.7434481087151483

# %% [markdown]
# ### LightGBM

# %%
modelLGB = LGBMClassifier(random_state = RANDOM_STATE)
param_search = {'learning_rate' : [0.1],
                'n_estimators' : [100, 200, 1000],
                'verbose': [0]
               }
gsearchLGB = GridSearchCV(estimator=modelLGB, cv=CROSSVAL,
                        param_grid=param_search,scoring = 'f1')

# %%
# %%time
gsearchLGB.fit(tf_idf_x_train, y_train)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 14.209110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 14.278682 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 13.724852 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 13.698539 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 13.823202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 13.938765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 17.491864 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 16.573078 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 17.497501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 17.803020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 14.061763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 57.895839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 22.096698 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 13.916272 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 13.731288 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 20.615603 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# CPU times: user 3h 28min 27s, sys: 57.6 s, total: 3h 29min 24s
# Wall time: 3h 31min 17s
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=42),
#              param_grid={'learning_rate': [0.1],
#                          'n_estimators': [100, 200, 1000], 'verbose': [0]},
#              scoring='f1')

# %%
print(gsearchLGB.best_score_)
print(gsearchLGB.best_params_)
# Out:
# 0.7668145344599745
# {'learning_rate': 0.1, 'n_estimators': 1000, 'verbose': 0}

# %% [markdown]
# С помощью классификатора LGBM достигнута целевая метрика на обучающей выборке, так как переход порога в 0,75 не очень большой, проверим работу модели BERT для данной выборки

# %% [markdown]
# ### BERT

# %% [markdown]
# Ищем видеокарту

# %%
print('torch.cuda.is_available() ', torch.cuda.is_available())
print('torch.cuda.current_device() ', torch.cuda.current_device())
print('torch.cuda.device_count()', torch.cuda.device_count())
print('torch.cuda.get_device_name(0)', torch.cuda.get_device_name(0))

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# torch.cuda.is_available()  True
# torch.cuda.current_device()  0
# torch.cuda.device_count() 1
# torch.cuda.get_device_name(0) Tesla M40
# cuda:0

# %% [markdown]
# Токенизатор

# %%
tokenizer = tf.BertTokenizer.from_pretrained('unitary/toxic-bert')

# %%
text = list(data['text'])

# %%
# %%time
tokenized = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
# Out:
# CPU times: user 7min 20s, sys: 17.9 s, total: 7min 38s
# Wall time: 7min 27s

# %% [markdown]
# Модель

# %%
model = transformers.BertModel.from_pretrained('unitary/toxic-bert')
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %% [markdown]
# Получаем эмбеддинги

# %%
# %%time
batch_size = 150
embeddings = []

for i in notebook.tqdm(range(tokenized['input_ids'].shape[0] // batch_size)):
    
        num_batches = tokenized['input_ids'].shape[0] // batch_size
        tokens = tokenized['input_ids'][batch_size*i:batch_size*(i+1)]
        token_types = tokenized['token_type_ids'][batch_size*i:batch_size*(i+1)]
        mask = tokenized['attention_mask'][batch_size*i:batch_size*(i+1)]
        
        batch = {'input_ids' : tokens.to(device),
                 'token_type_ids' : token_types.to(device), 
                 'attention_mask' : mask.to(device)}
        
        
        start_time = time.time()
        print(f"Processing batch {i+1}/{num_batches}")
                
        with torch.no_grad():
            batch_embeddings = model(**batch)
        
        embeddings.append(batch_embeddings[0][:,0,:].to('cpu').numpy())
        
        
        elapsed_time = time.time() - start_time
        remaining_batches = num_batches - (i + 1)
        remaining_time = elapsed_time * remaining_batches
        print(f"Batch {i+1} processed. Estimated time remaining: {remaining_time:.2f} sec ({(remaining_time/60):.2f} min)")
        
torch.cuda.empty_cache()
# Out:
#   0%|          | 0/1061 [00:00<?, ?it/s]
# Processing batch 1/1061
# Batch 1 processed. Estimated time remaining: 6307.12 sec (105.12 min)
# Processing batch 2/1061
# Batch 2 processed. Estimated time remaining: 8773.26 sec (146.22 min)
# Processing batch 3/1061
# Batch 3 processed. Estimated time remaining: 10092.57 sec (168.21 min)
# Processing batch 4/1061
# Batch 4 processed. Estimated time remaining: 10490.02 sec (174.83 min)
# Processing batch 5/1061
# Batch 5 processed. Estimated time remaining: 10641.26 sec (177.35 min)
# Processing batch 6/1061
# Batch 6 processed. Estimated time remaining: 10784.83 sec (179.75 min)
# Processing batch 7/1061
# Batch 7 processed. Estimated time remaining: 11056.60 sec (184.28 min)
# Processing batch 8/1061
# Batch 8 processed. Estimated time remaining: 11147.71 sec (185.80 min)
# Processing batch 9/1061
# Batch 9 processed. Estimated time remaining: 11019.74 sec (183.66 min)
# Processing batch 10/1061
# Batch 10 processed. Estimated time remaining: 11198.54 sec (186.64 min)
# Processing batch 11/1061
# Batch 11 processed. Estimated time remaining: 11104.35 sec (185.07 min)
# Processing batch 12/1061
# Batch 12 processed. Estimated time remaining: 11228.84 sec (187.15 min)
# Processing batch 13/1061
# Batch 13 processed. Estimated time remaining: 11125.16 sec (185.42 min)
# Processing batch 14/1061
# Batch 14 processed. Estimated time remaining: 10786.66 sec (179.78 min)
# Processing batch 15/1061
# Batch 15 processed. Estimated time remaining: 11052.78 sec (184.21 min)
# Processing batch 16/1061
# Batch 16 processed. Estimated time remaining: 11112.90 sec (185.22 min)
# Processing batch 17/1061
# Batch 17 processed. Estimated time remaining: 11059.83 sec (184.33 min)
# Processing batch 18/1061
# Batch 18 processed. Estimated time remaining: 10906.30 sec (181.77 min)
# Processing batch 19/1061
# Batch 19 processed. Estimated time remaining: 11146.85 sec (185.78 min)
# Processing batch 20/1061
# Batch 20 processed. Estimated time remaining: 10926.50 sec (182.11 min)
# Processing batch 21/1061
# Batch 21 processed. Estimated time remaining: 10844.08 sec (180.73 min)
# Processing batch 22/1061
# Batch 22 processed. Estimated time remaining: 11040.01 sec (184.00 min)
# Processing batch 23/1061
# Batch 23 processed. Estimated time remaining: 10658.27 sec (177.64 min)
# Processing batch 24/1061
# Batch 24 processed. Estimated time remaining: 11026.48 sec (183.77 min)
# Processing batch 25/1061
# Batch 25 processed. Estimated time remaining: 10923.71 sec (182.06 min)
# Processing batch 26/1061
# Batch 26 processed. Estimated time remaining: 10691.42 sec (178.19 min)
# Processing batch 27/1061
# Batch 27 processed. Estimated time remaining: 11051.17 sec (184.19 min)
# Processing batch 28/1061
# Batch 28 processed. Estimated time remaining: 10911.78 sec (181.86 min)
# Processing batch 29/1061
# Batch 29 processed. Estimated time remaining: 11069.61 sec (184.49 min)
# Processing batch 30/1061
# Batch 30 processed. Estimated time remaining: 10911.97 sec (181.87 min)
# Processing batch 31/1061
# Batch 31 processed. Estimated time remaining: 10916.22 sec (181.94 min)
# Processing batch 32/1061
# Batch 32 processed. Estimated time remaining: 10775.41 sec (179.59 min)
# Processing batch 33/1061
# Batch 33 processed. Estimated time remaining: 10887.65 sec (181.46 min)
# Processing batch 34/1061
# Batch 34 processed. Estimated time remaining: 11040.79 sec (184.01 min)
# Processing batch 35/1061
# Batch 35 processed. Estimated time remaining: 10799.05 sec (179.98 min)
# Processing batch 36/1061
# Batch 36 processed. Estimated time remaining: 10890.43 sec (181.51 min)
# Processing batch 37/1061
# Batch 37 processed. Estimated time remaining: 10722.95 sec (178.72 min)
# Processing batch 38/1061
# Batch 38 processed. Estimated time remaining: 10819.36 sec (180.32 min)
# Processing batch 39/1061
# Batch 39 processed. Estimated time remaining: 10849.24 sec (180.82 min)
# Processing batch 40/1061
# Batch 40 processed. Estimated time remaining: 10766.53 sec (179.44 min)
# Processing batch 41/1061
# Batch 41 processed. Estimated time remaining: 10753.02 sec (179.22 min)
# Processing batch 42/1061
# Batch 42 processed. Estimated time remaining: 10485.31 sec (174.76 min)
# Processing batch 43/1061
# Batch 43 processed. Estimated time remaining: 10702.98 sec (178.38 min)
# Processing batch 44/1061
# Batch 44 processed. Estimated time remaining: 10879.40 sec (181.32 min)
# Processing batch 45/1061
# Batch 45 processed. Estimated time remaining: 10654.16 sec (177.57 min)
# Processing batch 46/1061
# Batch 46 processed. Estimated time remaining: 10789.10 sec (179.82 min)
# Processing batch 47/1061
# Batch 47 processed. Estimated time remaining: 10771.68 sec (179.53 min)
# Processing batch 48/1061
# Batch 48 processed. Estimated time remaining: 10831.46 sec (180.52 min)
# Processing batch 49/1061
# Batch 49 processed. Estimated time remaining: 10610.92 sec (176.85 min)
# Processing batch 50/1061
# Batch 50 processed. Estimated time remaining: 10667.46 sec (177.79 min)
# Processing batch 51/1061
# Batch 51 processed. Estimated time remaining: 10792.62 sec (179.88 min)
# Processing batch 52/1061
# Batch 52 processed. Estimated time remaining: 10475.78 sec (174.60 min)
# Processing batch 53/1061
# Batch 53 processed. Estimated time remaining: 10741.76 sec (179.03 min)
# Processing batch 54/1061
# Batch 54 processed. Estimated time remaining: 10653.14 sec (177.55 min)
# Processing batch 55/1061
# Batch 55 processed. Estimated time remaining: 10671.69 sec (177.86 min)
# Processing batch 56/1061
# Batch 56 processed. Estimated time remaining: 10587.19 sec (176.45 min)
# Processing batch 57/1061
# Batch 57 processed. Estimated time remaining: 10325.69 sec (172.09 min)
# Processing batch 58/1061
# Batch 58 processed. Estimated time remaining: 10778.13 sec (179.64 min)
# Processing batch 59/1061
# Batch 59 processed. Estimated time remaining: 10514.23 sec (175.24 min)
# Processing batch 60/1061
# Batch 60 processed. Estimated time remaining: 10589.17 sec (176.49 min)
# Processing batch 61/1061
# Batch 61 processed. Estimated time remaining: 10408.30 sec (173.47 min)
# Processing batch 62/1061
# Batch 62 processed. Estimated time remaining: 10646.31 sec (177.44 min)
# Processing batch 63/1061
# Batch 63 processed. Estimated time remaining: 10435.80 sec (173.93 min)
# Processing batch 64/1061
# Batch 64 processed. Estimated time remaining: 10493.85 sec (174.90 min)
# Processing batch 65/1061
# Batch 65 processed. Estimated time remaining: 10489.15 sec (174.82 min)
# Processing batch 66/1061
# Batch 66 processed. Estimated time remaining: 10613.87 sec (176.90 min)
# Processing batch 67/1061
# Batch 67 processed. Estimated time remaining: 10555.08 sec (175.92 min)
# Processing batch 68/1061
# Batch 68 processed. Estimated time remaining: 10352.18 sec (172.54 min)
# Processing batch 69/1061
# Batch 69 processed. Estimated time remaining: 10594.61 sec (176.58 min)
# Processing batch 70/1061
# Batch 70 processed. Estimated time remaining: 10371.14 sec (172.85 min)
# Processing batch 71/1061
# Batch 71 processed. Estimated time remaining: 10304.50 sec (171.74 min)
# Processing batch 72/1061
# Batch 72 processed. Estimated time remaining: 10569.58 sec (176.16 min)
# Processing batch 73/1061
# Batch 73 processed. Estimated time remaining: 10372.38 sec (172.87 min)
# Processing batch 74/1061
# Batch 74 processed. Estimated time remaining: 10224.49 sec (170.41 min)
# Processing batch 75/1061
# Batch 75 processed. Estimated time remaining: 10463.29 sec (174.39 min)
# Processing batch 76/1061
# Batch 76 processed. Estimated time remaining: 10443.58 sec (174.06 min)
# Processing batch 77/1061
# Batch 77 processed. Estimated time remaining: 10439.75 sec (174.00 min)
# Processing batch 78/1061
# Batch 78 processed. Estimated time remaining: 10600.89 sec (176.68 min)
# Processing batch 79/1061
# Batch 79 processed. Estimated time remaining: 10371.96 sec (172.87 min)
# Processing batch 80/1061
# Batch 80 processed. Estimated time remaining: 10297.88 sec (171.63 min)
# Processing batch 81/1061
# Batch 81 processed. Estimated time remaining: 10269.30 sec (171.15 min)
# Processing batch 82/1061
# Batch 82 processed. Estimated time remaining: 10336.64 sec (172.28 min)
# Processing batch 83/1061
# Batch 83 processed. Estimated time remaining: 10467.97 sec (174.47 min)
# Processing batch 84/1061
# Batch 84 processed. Estimated time remaining: 10255.51 sec (170.93 min)
# Processing batch 85/1061
# Batch 85 processed. Estimated time remaining: 10270.27 sec (171.17 min)
# Processing batch 86/1061
# Batch 86 processed. Estimated time remaining: 10413.94 sec (173.57 min)
# Processing batch 87/1061
# Batch 87 processed. Estimated time remaining: 10322.27 sec (172.04 min)
# Processing batch 88/1061
# Batch 88 processed. Estimated time remaining: 10308.33 sec (171.81 min)
# Processing batch 89/1061
# Batch 89 processed. Estimated time remaining: 10129.36 sec (168.82 min)
# Processing batch 90/1061
# Batch 90 processed. Estimated time remaining: 10332.70 sec (172.21 min)
# Processing batch 91/1061
# Batch 91 processed. Estimated time remaining: 10127.80 sec (168.80 min)
# Processing batch 92/1061
# Batch 92 processed. Estimated time remaining: 10435.29 sec (173.92 min)
# Processing batch 93/1061
# Batch 93 processed. Estimated time remaining: 10168.85 sec (169.48 min)
# Processing batch 94/1061
# Batch 94 processed. Estimated time remaining: 10331.30 sec (172.19 min)
# Processing batch 95/1061
# Batch 95 processed. Estimated time remaining: 9966.77 sec (166.11 min)
# Processing batch 96/1061
# Batch 96 processed. Estimated time remaining: 10266.46 sec (171.11 min)
# Processing batch 97/1061
# Batch 97 processed. Estimated time remaining: 10083.45 sec (168.06 min)
# Processing batch 98/1061
# Batch 98 processed. Estimated time remaining: 10276.86 sec (171.28 min)
# Processing batch 99/1061
# Batch 99 processed. Estimated time remaining: 10182.45 sec (169.71 min)
# Processing batch 100/1061
# Batch 100 processed. Estimated time remaining: 10330.14 sec (172.17 min)
# Processing batch 101/1061
# Batch 101 processed. Estimated time remaining: 9986.40 sec (166.44 min)
# Processing batch 102/1061
# Batch 102 processed. Estimated time remaining: 10099.45 sec (168.32 min)
# Processing batch 103/1061
# Batch 103 processed. Estimated time remaining: 10279.35 sec (171.32 min)
# Processing batch 104/1061
# Batch 104 processed. Estimated time remaining: 9968.68 sec (166.14 min)
# Processing batch 105/1061
# Batch 105 processed. Estimated time remaining: 10213.40 sec (170.22 min)
# Processing batch 106/1061
# Batch 106 processed. Estimated time remaining: 10251.85 sec (170.86 min)
# Processing batch 107/1061
# Batch 107 processed. Estimated time remaining: 10101.83 sec (168.36 min)
# Processing batch 108/1061
# Batch 108 processed. Estimated time remaining: 9909.30 sec (165.16 min)
# Processing batch 109/1061
# Batch 109 processed. Estimated time remaining: 10005.67 sec (166.76 min)
# Processing batch 110/1061
# Batch 110 processed. Estimated time remaining: 10061.59 sec (167.69 min)
# Processing batch 111/1061
# Batch 111 processed. Estimated time remaining: 10090.78 sec (168.18 min)
# Processing batch 112/1061
# Batch 112 processed. Estimated time remaining: 10024.75 sec (167.08 min)
# Processing batch 113/1061
# Batch 113 processed. Estimated time remaining: 10000.86 sec (166.68 min)
# Processing batch 114/1061
# Batch 114 processed. Estimated time remaining: 9960.47 sec (166.01 min)
# Processing batch 115/1061
# Batch 115 processed. Estimated time remaining: 9994.42 sec (166.57 min)
# Processing batch 116/1061
# Batch 116 processed. Estimated time remaining: 10069.67 sec (167.83 min)
# Processing batch 117/1061
# Batch 117 processed. Estimated time remaining: 9991.80 sec (166.53 min)
# Processing batch 118/1061
# Batch 118 processed. Estimated time remaining: 9751.09 sec (162.52 min)
# Processing batch 119/1061
# Batch 119 processed. Estimated time remaining: 10009.72 sec (166.83 min)
# Processing batch 120/1061
# Batch 120 processed. Estimated time remaining: 9846.25 sec (164.10 min)
# Processing batch 121/1061
# Batch 121 processed. Estimated time remaining: 9969.45 sec (166.16 min)
# Processing batch 122/1061
# Batch 122 processed. Estimated time remaining: 9973.94 sec (166.23 min)
# Processing batch 123/1061
# Batch 123 processed. Estimated time remaining: 9771.10 sec (162.85 min)
# Processing batch 124/1061
# Batch 124 processed. Estimated time remaining: 9908.44 sec (165.14 min)
# Processing batch 125/1061
# Batch 125 processed. Estimated time remaining: 9849.49 sec (164.16 min)
# Processing batch 126/1061
# Batch 126 processed. Estimated time remaining: 9847.05 sec (164.12 min)
# Processing batch 127/1061
# Batch 127 processed. Estimated time remaining: 9801.41 sec (163.36 min)
# Processing batch 128/1061
# Batch 128 processed. Estimated time remaining: 9845.96 sec (164.10 min)
# Processing batch 129/1061
# Batch 129 processed. Estimated time remaining: 9908.85 sec (165.15 min)
# Processing batch 130/1061
# Batch 130 processed. Estimated time remaining: 9890.23 sec (164.84 min)
# Processing batch 131/1061
# Batch 131 processed. Estimated time remaining: 9566.60 sec (159.44 min)
# Processing batch 132/1061
# Batch 132 processed. Estimated time remaining: 9662.95 sec (161.05 min)
# Processing batch 133/1061
# Batch 133 processed. Estimated time remaining: 9841.61 sec (164.03 min)
# Processing batch 134/1061
# Batch 134 processed. Estimated time remaining: 9722.54 sec (162.04 min)
# Processing batch 135/1061
# Batch 135 processed. Estimated time remaining: 9816.35 sec (163.61 min)
# Processing batch 136/1061
# Batch 136 processed. Estimated time remaining: 9731.31 sec (162.19 min)
# Processing batch 137/1061
# Batch 137 processed. Estimated time remaining: 9802.91 sec (163.38 min)
# Processing batch 138/1061
# Batch 138 processed. Estimated time remaining: 9605.79 sec (160.10 min)
# Processing batch 139/1061
# Batch 139 processed. Estimated time remaining: 9699.00 sec (161.65 min)
# Processing batch 140/1061
# Batch 140 processed. Estimated time remaining: 9653.99 sec (160.90 min)
# Processing batch 141/1061
# Batch 141 processed. Estimated time remaining: 9761.77 sec (162.70 min)
# Processing batch 142/1061
# Batch 142 processed. Estimated time remaining: 9621.83 sec (160.36 min)
# Processing batch 143/1061
# Batch 143 processed. Estimated time remaining: 9771.77 sec (162.86 min)
# Processing batch 144/1061
# Batch 144 processed. Estimated time remaining: 9818.88 sec (163.65 min)
# Processing batch 145/1061
# Batch 145 processed. Estimated time remaining: 9639.70 sec (160.66 min)
# Processing batch 146/1061
# Batch 146 processed. Estimated time remaining: 9693.89 sec (161.56 min)
# Processing batch 147/1061
# Batch 147 processed. Estimated time remaining: 9741.71 sec (162.36 min)
# Processing batch 148/1061
# Batch 148 processed. Estimated time remaining: 9651.39 sec (160.86 min)
# Processing batch 149/1061
# Batch 149 processed. Estimated time remaining: 9512.05 sec (158.53 min)
# Processing batch 150/1061
# Batch 150 processed. Estimated time remaining: 9606.83 sec (160.11 min)
# Processing batch 151/1061
# Batch 151 processed. Estimated time remaining: 9501.31 sec (158.36 min)
# Processing batch 152/1061
# Batch 152 processed. Estimated time remaining: 9629.15 sec (160.49 min)
# Processing batch 153/1061
# Batch 153 processed. Estimated time remaining: 9608.91 sec (160.15 min)
# Processing batch 154/1061
# Batch 154 processed. Estimated time remaining: 9615.05 sec (160.25 min)
# Processing batch 155/1061
# Batch 155 processed. Estimated time remaining: 9575.98 sec (159.60 min)
# Processing batch 156/1061
# Batch 156 processed. Estimated time remaining: 9450.53 sec (157.51 min)
# Processing batch 157/1061
# Batch 157 processed. Estimated time remaining: 9583.45 sec (159.72 min)
# Processing batch 158/1061
# Batch 158 processed. Estimated time remaining: 9465.23 sec (157.75 min)
# Processing batch 159/1061
# Batch 159 processed. Estimated time remaining: 9517.22 sec (158.62 min)
# Processing batch 160/1061
# Batch 160 processed. Estimated time remaining: 9569.03 sec (159.48 min)
# Processing batch 161/1061
# Batch 161 processed. Estimated time remaining: 9317.60 sec (155.29 min)
# Processing batch 162/1061
# Batch 162 processed. Estimated time remaining: 9547.94 sec (159.13 min)
# Processing batch 163/1061
# Batch 163 processed. Estimated time remaining: 9516.54 sec (158.61 min)
# Processing batch 164/1061
# Batch 164 processed. Estimated time remaining: 9484.86 sec (158.08 min)
# Processing batch 165/1061
# Batch 165 processed. Estimated time remaining: 9551.65 sec (159.19 min)
# Processing batch 166/1061
# Batch 166 processed. Estimated time remaining: 9282.66 sec (154.71 min)
# Processing batch 167/1061
# Batch 167 processed. Estimated time remaining: 9331.73 sec (155.53 min)
# Processing batch 168/1061
# Batch 168 processed. Estimated time remaining: 9407.20 sec (156.79 min)
# Processing batch 169/1061
# Batch 169 processed. Estimated time remaining: 9591.56 sec (159.86 min)
# Processing batch 170/1061
# Batch 170 processed. Estimated time remaining: 9383.67 sec (156.39 min)
# Processing batch 171/1061
# Batch 171 processed. Estimated time remaining: 9406.87 sec (156.78 min)
# Processing batch 172/1061
# Batch 172 processed. Estimated time remaining: 9412.07 sec (156.87 min)
# Processing batch 173/1061
# Batch 173 processed. Estimated time remaining: 9333.19 sec (155.55 min)
# Processing batch 174/1061
# Batch 174 processed. Estimated time remaining: 9439.73 sec (157.33 min)
# Processing batch 175/1061
# Batch 175 processed. Estimated time remaining: 9335.11 sec (155.59 min)
# Processing batch 176/1061
# Batch 176 processed. Estimated time remaining: 9406.60 sec (156.78 min)
# Processing batch 177/1061
# Batch 177 processed. Estimated time remaining: 9344.40 sec (155.74 min)
# Processing batch 178/1061
# Batch 178 processed. Estimated time remaining: 9381.90 sec (156.37 min)
# Processing batch 179/1061
# Batch 179 processed. Estimated time remaining: 9409.63 sec (156.83 min)
# Processing batch 180/1061
# Batch 180 processed. Estimated time remaining: 9190.56 sec (153.18 min)
# Processing batch 181/1061
# Batch 181 processed. Estimated time remaining: 9331.34 sec (155.52 min)
# Processing batch 182/1061
# Batch 182 processed. Estimated time remaining: 9365.93 sec (156.10 min)
# Processing batch 183/1061
# Batch 183 processed. Estimated time remaining: 9323.67 sec (155.39 min)
# Processing batch 184/1061
# Batch 184 processed. Estimated time remaining: 9211.10 sec (153.52 min)
# Processing batch 185/1061
# Batch 185 processed. Estimated time remaining: 9150.68 sec (152.51 min)
# Processing batch 186/1061
# Batch 186 processed. Estimated time remaining: 9450.95 sec (157.52 min)
# Processing batch 187/1061
# Batch 187 processed. Estimated time remaining: 9071.08 sec (151.18 min)
# Processing batch 188/1061
# Batch 188 processed. Estimated time remaining: 9169.67 sec (152.83 min)
# Processing batch 189/1061
# Batch 189 processed. Estimated time remaining: 9172.91 sec (152.88 min)
# Processing batch 190/1061
# Batch 190 processed. Estimated time remaining: 9251.38 sec (154.19 min)
# Processing batch 191/1061
# Batch 191 processed. Estimated time remaining: 9235.74 sec (153.93 min)
# Processing batch 192/1061
# Batch 192 processed. Estimated time remaining: 9145.91 sec (152.43 min)
# Processing batch 193/1061
# Batch 193 processed. Estimated time remaining: 9319.87 sec (155.33 min)
# Processing batch 194/1061
# Batch 194 processed. Estimated time remaining: 9181.64 sec (153.03 min)
# Processing batch 195/1061
# Batch 195 processed. Estimated time remaining: 9155.48 sec (152.59 min)
# Processing batch 196/1061
# Batch 196 processed. Estimated time remaining: 9175.01 sec (152.92 min)
# Processing batch 197/1061
# Batch 197 processed. Estimated time remaining: 9201.70 sec (153.36 min)
# Processing batch 198/1061
# Batch 198 processed. Estimated time remaining: 9079.99 sec (151.33 min)
# Processing batch 199/1061
# Batch 199 processed. Estimated time remaining: 9256.59 sec (154.28 min)
# Processing batch 200/1061
# Batch 200 processed. Estimated time remaining: 9093.18 sec (151.55 min)
# Processing batch 201/1061
# Batch 201 processed. Estimated time remaining: 9183.49 sec (153.06 min)
# Processing batch 202/1061
# Batch 202 processed. Estimated time remaining: 9106.21 sec (151.77 min)
# Processing batch 203/1061
# Batch 203 processed. Estimated time remaining: 9043.92 sec (150.73 min)
# Processing batch 204/1061
# Batch 204 processed. Estimated time remaining: 9035.73 sec (150.60 min)
# Processing batch 205/1061
# Batch 205 processed. Estimated time remaining: 9151.41 sec (152.52 min)
# Processing batch 206/1061
# Batch 206 processed. Estimated time remaining: 8994.21 sec (149.90 min)
# Processing batch 207/1061
# Batch 207 processed. Estimated time remaining: 9269.71 sec (154.50 min)
# Processing batch 208/1061
# Batch 208 processed. Estimated time remaining: 8766.41 sec (146.11 min)
# Processing batch 209/1061
# Batch 209 processed. Estimated time remaining: 9129.00 sec (152.15 min)
# Processing batch 210/1061
# Batch 210 processed. Estimated time remaining: 9064.96 sec (151.08 min)
# Processing batch 211/1061
# Batch 211 processed. Estimated time remaining: 9118.89 sec (151.98 min)
# Processing batch 212/1061
# Batch 212 processed. Estimated time remaining: 8784.52 sec (146.41 min)
# Processing batch 213/1061
# Batch 213 processed. Estimated time remaining: 9025.01 sec (150.42 min)
# Processing batch 214/1061
# Batch 214 processed. Estimated time remaining: 8944.45 sec (149.07 min)
# Processing batch 215/1061
# Batch 215 processed. Estimated time remaining: 9005.96 sec (150.10 min)
# Processing batch 216/1061
# Batch 216 processed. Estimated time remaining: 8890.85 sec (148.18 min)
# Processing batch 217/1061
# Batch 217 processed. Estimated time remaining: 8835.48 sec (147.26 min)
# Processing batch 218/1061
# Batch 218 processed. Estimated time remaining: 9023.49 sec (150.39 min)
# Processing batch 219/1061
# Batch 219 processed. Estimated time remaining: 8825.17 sec (147.09 min)
# Processing batch 220/1061
# Batch 220 processed. Estimated time remaining: 8844.92 sec (147.42 min)
# Processing batch 221/1061
# Batch 221 processed. Estimated time remaining: 8882.25 sec (148.04 min)
# Processing batch 222/1061
# Batch 222 processed. Estimated time remaining: 8927.92 sec (148.80 min)
# Processing batch 223/1061
# Batch 223 processed. Estimated time remaining: 8828.39 sec (147.14 min)
# Processing batch 224/1061
# Batch 224 processed. Estimated time remaining: 8866.02 sec (147.77 min)
# Processing batch 225/1061
# Batch 225 processed. Estimated time remaining: 8894.31 sec (148.24 min)
# Processing batch 226/1061
# Batch 226 processed. Estimated time remaining: 8881.88 sec (148.03 min)
# Processing batch 227/1061
# Batch 227 processed. Estimated time remaining: 8767.80 sec (146.13 min)
# Processing batch 228/1061
# Batch 228 processed. Estimated time remaining: 8881.87 sec (148.03 min)
# Processing batch 229/1061
# Batch 229 processed. Estimated time remaining: 8580.31 sec (143.01 min)
# Processing batch 230/1061
# Batch 230 processed. Estimated time remaining: 8958.26 sec (149.30 min)
# Processing batch 231/1061
# Batch 231 processed. Estimated time remaining: 8724.41 sec (145.41 min)
# Processing batch 232/1061
# Batch 232 processed. Estimated time remaining: 8836.12 sec (147.27 min)
# Processing batch 233/1061
# Batch 233 processed. Estimated time remaining: 8750.30 sec (145.84 min)
# Processing batch 234/1061
# Batch 234 processed. Estimated time remaining: 8686.52 sec (144.78 min)
# Processing batch 235/1061
# Batch 235 processed. Estimated time remaining: 8878.24 sec (147.97 min)
# Processing batch 236/1061
# Batch 236 processed. Estimated time remaining: 8696.55 sec (144.94 min)
# Processing batch 237/1061
# Batch 237 processed. Estimated time remaining: 8697.39 sec (144.96 min)
# Processing batch 238/1061
# Batch 238 processed. Estimated time remaining: 8666.47 sec (144.44 min)
# Processing batch 239/1061
# Batch 239 processed. Estimated time remaining: 8511.80 sec (141.86 min)
# Processing batch 240/1061
# Batch 240 processed. Estimated time remaining: 8802.54 sec (146.71 min)
# Processing batch 241/1061
# Batch 241 processed. Estimated time remaining: 8719.38 sec (145.32 min)
# Processing batch 242/1061
# Batch 242 processed. Estimated time remaining: 8631.07 sec (143.85 min)
# Processing batch 243/1061
# Batch 243 processed. Estimated time remaining: 8705.68 sec (145.09 min)
# Processing batch 244/1061
# Batch 244 processed. Estimated time remaining: 8841.53 sec (147.36 min)
# Processing batch 245/1061
# Batch 245 processed. Estimated time remaining: 8671.95 sec (144.53 min)
# Processing batch 246/1061
# Batch 246 processed. Estimated time remaining: 8780.60 sec (146.34 min)
# Processing batch 247/1061
# Batch 247 processed. Estimated time remaining: 8431.27 sec (140.52 min)
# Processing batch 248/1061
# Batch 248 processed. Estimated time remaining: 8493.46 sec (141.56 min)
# Processing batch 249/1061
# Batch 249 processed. Estimated time remaining: 8677.57 sec (144.63 min)
# Processing batch 250/1061
# Batch 250 processed. Estimated time remaining: 8526.38 sec (142.11 min)
# Processing batch 251/1061
# Batch 251 processed. Estimated time remaining: 8706.53 sec (145.11 min)
# Processing batch 252/1061
# Batch 252 processed. Estimated time remaining: 8615.80 sec (143.60 min)
# Processing batch 253/1061
# Batch 253 processed. Estimated time remaining: 8486.62 sec (141.44 min)
# Processing batch 254/1061
# Batch 254 processed. Estimated time remaining: 8575.49 sec (142.92 min)
# Processing batch 255/1061
# Batch 255 processed. Estimated time remaining: 8510.50 sec (141.84 min)
# Processing batch 256/1061
# Batch 256 processed. Estimated time remaining: 8645.51 sec (144.09 min)
# Processing batch 257/1061
# Batch 257 processed. Estimated time remaining: 8498.32 sec (141.64 min)
# Processing batch 258/1061
# Batch 258 processed. Estimated time remaining: 8620.29 sec (143.67 min)
# Processing batch 259/1061
# Batch 259 processed. Estimated time remaining: 8556.85 sec (142.61 min)
# Processing batch 260/1061
# Batch 260 processed. Estimated time remaining: 8495.09 sec (141.58 min)
# Processing batch 261/1061
# Batch 261 processed. Estimated time remaining: 8416.64 sec (140.28 min)
# Processing batch 262/1061
# Batch 262 processed. Estimated time remaining: 8342.75 sec (139.05 min)
# Processing batch 263/1061
# Batch 263 processed. Estimated time remaining: 8467.75 sec (141.13 min)
# Processing batch 264/1061
# Batch 264 processed. Estimated time remaining: 8311.13 sec (138.52 min)
# Processing batch 265/1061
# Batch 265 processed. Estimated time remaining: 8348.42 sec (139.14 min)
# Processing batch 266/1061
# Batch 266 processed. Estimated time remaining: 8594.55 sec (143.24 min)
# Processing batch 267/1061
# Batch 267 processed. Estimated time remaining: 8390.64 sec (139.84 min)
# Processing batch 268/1061
# Batch 268 processed. Estimated time remaining: 8338.67 sec (138.98 min)
# Processing batch 269/1061
# Batch 269 processed. Estimated time remaining: 8350.04 sec (139.17 min)
# Processing batch 270/1061
# Batch 270 processed. Estimated time remaining: 8537.75 sec (142.30 min)
# Processing batch 271/1061
# Batch 271 processed. Estimated time remaining: 8353.00 sec (139.22 min)
# Processing batch 272/1061
# Batch 272 processed. Estimated time remaining: 8339.38 sec (138.99 min)
# Processing batch 273/1061
# Batch 273 processed. Estimated time remaining: 8328.68 sec (138.81 min)
# Processing batch 274/1061
# Batch 274 processed. Estimated time remaining: 8379.75 sec (139.66 min)
# Processing batch 275/1061
# Batch 275 processed. Estimated time remaining: 8353.71 sec (139.23 min)
# Processing batch 276/1061
# Batch 276 processed. Estimated time remaining: 8451.60 sec (140.86 min)
# Processing batch 277/1061
# Batch 277 processed. Estimated time remaining: 8439.16 sec (140.65 min)
# Processing batch 278/1061
# Batch 278 processed. Estimated time remaining: 8263.79 sec (137.73 min)
# Processing batch 279/1061
# Batch 279 processed. Estimated time remaining: 8196.21 sec (136.60 min)
# Processing batch 280/1061
# Batch 280 processed. Estimated time remaining: 8225.53 sec (137.09 min)
# Processing batch 281/1061
# Batch 281 processed. Estimated time remaining: 8292.30 sec (138.20 min)
# Processing batch 282/1061
# Batch 282 processed. Estimated time remaining: 8340.86 sec (139.01 min)
# Processing batch 283/1061
# Batch 283 processed. Estimated time remaining: 8235.51 sec (137.26 min)
# Processing batch 284/1061
# Batch 284 processed. Estimated time remaining: 8257.72 sec (137.63 min)
# Processing batch 285/1061
# Batch 285 processed. Estimated time remaining: 8186.95 sec (136.45 min)
# Processing batch 286/1061
# Batch 286 processed. Estimated time remaining: 8193.38 sec (136.56 min)
# Processing batch 287/1061
# Batch 287 processed. Estimated time remaining: 8126.13 sec (135.44 min)
# Processing batch 288/1061
# Batch 288 processed. Estimated time remaining: 8171.83 sec (136.20 min)
# Processing batch 289/1061
# Batch 289 processed. Estimated time remaining: 8136.62 sec (135.61 min)
# Processing batch 290/1061
# Batch 290 processed. Estimated time remaining: 8208.49 sec (136.81 min)
# Processing batch 291/1061
# Batch 291 processed. Estimated time remaining: 8062.73 sec (134.38 min)
# Processing batch 292/1061
# Batch 292 processed. Estimated time remaining: 8086.38 sec (134.77 min)
# Processing batch 293/1061
# Batch 293 processed. Estimated time remaining: 8054.31 sec (134.24 min)
# Processing batch 294/1061
# Batch 294 processed. Estimated time remaining: 8259.63 sec (137.66 min)
# Processing batch 295/1061
# Batch 295 processed. Estimated time remaining: 8191.01 sec (136.52 min)
# Processing batch 296/1061
# Batch 296 processed. Estimated time remaining: 8111.48 sec (135.19 min)
# Processing batch 297/1061
# Batch 297 processed. Estimated time remaining: 8077.27 sec (134.62 min)
# Processing batch 298/1061
# Batch 298 processed. Estimated time remaining: 8119.46 sec (135.32 min)
# Processing batch 299/1061
# Batch 299 processed. Estimated time remaining: 8080.39 sec (134.67 min)
# Processing batch 300/1061
# Batch 300 processed. Estimated time remaining: 8055.82 sec (134.26 min)
# Processing batch 301/1061
# Batch 301 processed. Estimated time remaining: 8025.06 sec (133.75 min)
# Processing batch 302/1061
# Batch 302 processed. Estimated time remaining: 8015.41 sec (133.59 min)
# Processing batch 303/1061
# Batch 303 processed. Estimated time remaining: 8106.69 sec (135.11 min)
# Processing batch 304/1061
# Batch 304 processed. Estimated time remaining: 8148.19 sec (135.80 min)
# Processing batch 305/1061
# Batch 305 processed. Estimated time remaining: 8014.02 sec (133.57 min)
# Processing batch 306/1061
# Batch 306 processed. Estimated time remaining: 8182.39 sec (136.37 min)
# Processing batch 307/1061
# Batch 307 processed. Estimated time remaining: 7915.82 sec (131.93 min)
# Processing batch 308/1061
# Batch 308 processed. Estimated time remaining: 8020.67 sec (133.68 min)
# Processing batch 309/1061
# Batch 309 processed. Estimated time remaining: 8027.05 sec (133.78 min)
# Processing batch 310/1061
# Batch 310 processed. Estimated time remaining: 8095.31 sec (134.92 min)
# Processing batch 311/1061
# Batch 311 processed. Estimated time remaining: 7773.43 sec (129.56 min)
# Processing batch 312/1061
# Batch 312 processed. Estimated time remaining: 8043.35 sec (134.06 min)
# Processing batch 313/1061
# Batch 313 processed. Estimated time remaining: 7962.55 sec (132.71 min)
# Processing batch 314/1061
# Batch 314 processed. Estimated time remaining: 7944.58 sec (132.41 min)
# Processing batch 315/1061
# Batch 315 processed. Estimated time remaining: 7905.66 sec (131.76 min)
# Processing batch 316/1061
# Batch 316 processed. Estimated time remaining: 7887.62 sec (131.46 min)
# Processing batch 317/1061
# Batch 317 processed. Estimated time remaining: 7789.25 sec (129.82 min)
# Processing batch 318/1061
# Batch 318 processed. Estimated time remaining: 7784.50 sec (129.74 min)
# Processing batch 319/1061
# Batch 319 processed. Estimated time remaining: 7905.32 sec (131.76 min)
# Processing batch 320/1061
# Batch 320 processed. Estimated time remaining: 7876.95 sec (131.28 min)
# Processing batch 321/1061
# Batch 321 processed. Estimated time remaining: 7734.72 sec (128.91 min)
# Processing batch 322/1061
# Batch 322 processed. Estimated time remaining: 7748.02 sec (129.13 min)
# Processing batch 323/1061
# Batch 323 processed. Estimated time remaining: 7934.68 sec (132.24 min)
# Processing batch 324/1061
# Batch 324 processed. Estimated time remaining: 7850.96 sec (130.85 min)
# Processing batch 325/1061
# Batch 325 processed. Estimated time remaining: 7769.79 sec (129.50 min)
# Processing batch 326/1061
# Batch 326 processed. Estimated time remaining: 7809.32 sec (130.16 min)
# Processing batch 327/1061
# Batch 327 processed. Estimated time remaining: 7830.50 sec (130.51 min)
# Processing batch 328/1061
# Batch 328 processed. Estimated time remaining: 7889.84 sec (131.50 min)
# Processing batch 329/1061
# Batch 329 processed. Estimated time remaining: 7959.73 sec (132.66 min)
# Processing batch 330/1061
# Batch 330 processed. Estimated time remaining: 7636.63 sec (127.28 min)
# Processing batch 331/1061
# Batch 331 processed. Estimated time remaining: 7732.55 sec (128.88 min)
# Processing batch 332/1061
# Batch 332 processed. Estimated time remaining: 7729.49 sec (128.82 min)
# Processing batch 333/1061
# Batch 333 processed. Estimated time remaining: 7689.00 sec (128.15 min)
# Processing batch 334/1061
# Batch 334 processed. Estimated time remaining: 7642.74 sec (127.38 min)
# Processing batch 335/1061
# Batch 335 processed. Estimated time remaining: 7823.36 sec (130.39 min)
# Processing batch 336/1061
# Batch 336 processed. Estimated time remaining: 7706.90 sec (128.45 min)
# Processing batch 337/1061
# Batch 337 processed. Estimated time remaining: 7752.80 sec (129.21 min)
# Processing batch 338/1061
# Batch 338 processed. Estimated time remaining: 7683.27 sec (128.05 min)
# Processing batch 339/1061
# Batch 339 processed. Estimated time remaining: 7711.50 sec (128.53 min)
# Processing batch 340/1061
# Batch 340 processed. Estimated time remaining: 7646.46 sec (127.44 min)
# Processing batch 341/1061
# Batch 341 processed. Estimated time remaining: 7749.55 sec (129.16 min)
# Processing batch 342/1061
# Batch 342 processed. Estimated time remaining: 7580.08 sec (126.33 min)
# Processing batch 343/1061
# Batch 343 processed. Estimated time remaining: 7575.92 sec (126.27 min)
# Processing batch 344/1061
# Batch 344 processed. Estimated time remaining: 7751.96 sec (129.20 min)
# Processing batch 345/1061
# Batch 345 processed. Estimated time remaining: 7567.61 sec (126.13 min)
# Processing batch 346/1061
# Batch 346 processed. Estimated time remaining: 7648.54 sec (127.48 min)
# Processing batch 347/1061
# Batch 347 processed. Estimated time remaining: 7658.63 sec (127.64 min)
# Processing batch 348/1061
# Batch 348 processed. Estimated time remaining: 7448.55 sec (124.14 min)
# Processing batch 349/1061
# Batch 349 processed. Estimated time remaining: 7523.40 sec (125.39 min)
# Processing batch 350/1061
# Batch 350 processed. Estimated time remaining: 7669.03 sec (127.82 min)
# Processing batch 351/1061
# Batch 351 processed. Estimated time remaining: 7531.21 sec (125.52 min)
# Processing batch 352/1061
# Batch 352 processed. Estimated time remaining: 7327.68 sec (122.13 min)
# Processing batch 353/1061
# Batch 353 processed. Estimated time remaining: 7439.94 sec (124.00 min)
# Processing batch 354/1061
# Batch 354 processed. Estimated time remaining: 7468.84 sec (124.48 min)
# Processing batch 355/1061
# Batch 355 processed. Estimated time remaining: 7502.69 sec (125.04 min)
# Processing batch 356/1061
# Batch 356 processed. Estimated time remaining: 7606.60 sec (126.78 min)
# Processing batch 357/1061
# Batch 357 processed. Estimated time remaining: 7566.71 sec (126.11 min)
# Processing batch 358/1061
# Batch 358 processed. Estimated time remaining: 7571.55 sec (126.19 min)
# Processing batch 359/1061
# Batch 359 processed. Estimated time remaining: 7425.39 sec (123.76 min)
# Processing batch 360/1061
# Batch 360 processed. Estimated time remaining: 7458.85 sec (124.31 min)
# Processing batch 361/1061
# Batch 361 processed. Estimated time remaining: 7501.41 sec (125.02 min)
# Processing batch 362/1061
# Batch 362 processed. Estimated time remaining: 7486.53 sec (124.78 min)
# Processing batch 363/1061
# Batch 363 processed. Estimated time remaining: 7482.40 sec (124.71 min)
# Processing batch 364/1061
# Batch 364 processed. Estimated time remaining: 7415.90 sec (123.60 min)
# Processing batch 365/1061
# Batch 365 processed. Estimated time remaining: 7424.84 sec (123.75 min)
# Processing batch 366/1061
# Batch 366 processed. Estimated time remaining: 7420.17 sec (123.67 min)
# Processing batch 367/1061
# Batch 367 processed. Estimated time remaining: 7394.01 sec (123.23 min)
# Processing batch 368/1061
# Batch 368 processed. Estimated time remaining: 7233.88 sec (120.56 min)
# Processing batch 369/1061
# Batch 369 processed. Estimated time remaining: 7362.16 sec (122.70 min)
# Processing batch 370/1061
# Batch 370 processed. Estimated time remaining: 7472.00 sec (124.53 min)
# Processing batch 371/1061
# Batch 371 processed. Estimated time remaining: 7337.50 sec (122.29 min)
# Processing batch 372/1061
# Batch 372 processed. Estimated time remaining: 7250.28 sec (120.84 min)
# Processing batch 373/1061
# Batch 373 processed. Estimated time remaining: 7182.96 sec (119.72 min)
# Processing batch 374/1061
# Batch 374 processed. Estimated time remaining: 7344.13 sec (122.40 min)
# Processing batch 375/1061
# Batch 375 processed. Estimated time remaining: 7421.87 sec (123.70 min)
# Processing batch 376/1061
# Batch 376 processed. Estimated time remaining: 7141.45 sec (119.02 min)
# Processing batch 377/1061
# Batch 377 processed. Estimated time remaining: 7238.15 sec (120.64 min)
# Processing batch 378/1061
# Batch 378 processed. Estimated time remaining: 7363.36 sec (122.72 min)
# Processing batch 379/1061
# Batch 379 processed. Estimated time remaining: 7170.54 sec (119.51 min)
# Processing batch 380/1061
# Batch 380 processed. Estimated time remaining: 7302.13 sec (121.70 min)
# Processing batch 381/1061
# Batch 381 processed. Estimated time remaining: 7245.41 sec (120.76 min)
# Processing batch 382/1061
# Batch 382 processed. Estimated time remaining: 7172.07 sec (119.53 min)
# Processing batch 383/1061
# Batch 383 processed. Estimated time remaining: 7261.63 sec (121.03 min)
# Processing batch 384/1061
# Batch 384 processed. Estimated time remaining: 7168.76 sec (119.48 min)
# Processing batch 385/1061
# Batch 385 processed. Estimated time remaining: 7208.94 sec (120.15 min)
# Processing batch 386/1061
# Batch 386 processed. Estimated time remaining: 7222.59 sec (120.38 min)
# Processing batch 387/1061
# Batch 387 processed. Estimated time remaining: 7137.48 sec (118.96 min)
# Processing batch 388/1061
# Batch 388 processed. Estimated time remaining: 7129.85 sec (118.83 min)
# Processing batch 389/1061
# Batch 389 processed. Estimated time remaining: 7006.00 sec (116.77 min)
# Processing batch 390/1061
# Batch 390 processed. Estimated time remaining: 7118.19 sec (118.64 min)
# Processing batch 391/1061
# Batch 391 processed. Estimated time remaining: 7103.11 sec (118.39 min)
# Processing batch 392/1061
# Batch 392 processed. Estimated time remaining: 7123.25 sec (118.72 min)
# Processing batch 393/1061
# Batch 393 processed. Estimated time remaining: 7108.17 sec (118.47 min)
# Processing batch 394/1061
# Batch 394 processed. Estimated time remaining: 7080.21 sec (118.00 min)
# Processing batch 395/1061
# Batch 395 processed. Estimated time remaining: 7189.82 sec (119.83 min)
# Processing batch 396/1061
# Batch 396 processed. Estimated time remaining: 6980.00 sec (116.33 min)
# Processing batch 397/1061
# Batch 397 processed. Estimated time remaining: 7062.40 sec (117.71 min)
# Processing batch 398/1061
# Batch 398 processed. Estimated time remaining: 6907.86 sec (115.13 min)
# Processing batch 399/1061
# Batch 399 processed. Estimated time remaining: 7053.07 sec (117.55 min)
# Processing batch 400/1061
# Batch 400 processed. Estimated time remaining: 6976.70 sec (116.28 min)
# Processing batch 401/1061
# Batch 401 processed. Estimated time remaining: 7059.18 sec (117.65 min)
# Processing batch 402/1061
# Batch 402 processed. Estimated time remaining: 7013.69 sec (116.89 min)
# Processing batch 403/1061
# Batch 403 processed. Estimated time remaining: 6925.09 sec (115.42 min)
# Processing batch 404/1061
# Batch 404 processed. Estimated time remaining: 7066.34 sec (117.77 min)
# Processing batch 405/1061
# Batch 405 processed. Estimated time remaining: 7051.29 sec (117.52 min)
# Processing batch 406/1061
# Batch 406 processed. Estimated time remaining: 6915.79 sec (115.26 min)
# Processing batch 407/1061
# Batch 407 processed. Estimated time remaining: 7066.18 sec (117.77 min)
# Processing batch 408/1061
# Batch 408 processed. Estimated time remaining: 6976.60 sec (116.28 min)
# Processing batch 409/1061
# Batch 409 processed. Estimated time remaining: 6933.97 sec (115.57 min)
# Processing batch 410/1061
# Batch 410 processed. Estimated time remaining: 6826.83 sec (113.78 min)
# Processing batch 411/1061
# Batch 411 processed. Estimated time remaining: 6938.88 sec (115.65 min)
# Processing batch 412/1061
# Batch 412 processed. Estimated time remaining: 6928.97 sec (115.48 min)
# Processing batch 413/1061
# Batch 413 processed. Estimated time remaining: 6845.65 sec (114.09 min)
# Processing batch 414/1061
# Batch 414 processed. Estimated time remaining: 6850.07 sec (114.17 min)
# Processing batch 415/1061
# Batch 415 processed. Estimated time remaining: 6908.30 sec (115.14 min)
# Processing batch 416/1061
# Batch 416 processed. Estimated time remaining: 6786.84 sec (113.11 min)
# Processing batch 417/1061
# Batch 417 processed. Estimated time remaining: 6913.65 sec (115.23 min)
# Processing batch 418/1061
# Batch 418 processed. Estimated time remaining: 6745.67 sec (112.43 min)
# Processing batch 419/1061
# Batch 419 processed. Estimated time remaining: 6877.66 sec (114.63 min)
# Processing batch 420/1061
# Batch 420 processed. Estimated time remaining: 6883.69 sec (114.73 min)
# Processing batch 421/1061
# Batch 421 processed. Estimated time remaining: 6660.34 sec (111.01 min)
# Processing batch 422/1061
# Batch 422 processed. Estimated time remaining: 6825.52 sec (113.76 min)
# Processing batch 423/1061
# Batch 423 processed. Estimated time remaining: 6697.70 sec (111.63 min)
# Processing batch 424/1061
# Batch 424 processed. Estimated time remaining: 6778.80 sec (112.98 min)
# Processing batch 425/1061
# Batch 425 processed. Estimated time remaining: 6705.68 sec (111.76 min)
# Processing batch 426/1061
# Batch 426 processed. Estimated time remaining: 6793.62 sec (113.23 min)
# Processing batch 427/1061
# Batch 427 processed. Estimated time remaining: 6703.09 sec (111.72 min)
# Processing batch 428/1061
# Batch 428 processed. Estimated time remaining: 6745.99 sec (112.43 min)
# Processing batch 429/1061
# Batch 429 processed. Estimated time remaining: 6737.81 sec (112.30 min)
# Processing batch 430/1061
# Batch 430 processed. Estimated time remaining: 6814.78 sec (113.58 min)
# Processing batch 431/1061
# Batch 431 processed. Estimated time remaining: 6675.55 sec (111.26 min)
# Processing batch 432/1061
# Batch 432 processed. Estimated time remaining: 6724.97 sec (112.08 min)
# Processing batch 433/1061
# Batch 433 processed. Estimated time remaining: 6577.64 sec (109.63 min)
# Processing batch 434/1061
# Batch 434 processed. Estimated time remaining: 6524.74 sec (108.75 min)
# Processing batch 435/1061
# Batch 435 processed. Estimated time remaining: 6557.18 sec (109.29 min)
# Processing batch 436/1061
# Batch 436 processed. Estimated time remaining: 6642.69 sec (110.71 min)
# Processing batch 437/1061
# Batch 437 processed. Estimated time remaining: 6540.20 sec (109.00 min)
# Processing batch 438/1061
# Batch 438 processed. Estimated time remaining: 6568.08 sec (109.47 min)
# Processing batch 439/1061
# Batch 439 processed. Estimated time remaining: 6685.12 sec (111.42 min)
# Processing batch 440/1061
# Batch 440 processed. Estimated time remaining: 6543.92 sec (109.07 min)
# Processing batch 441/1061
# Batch 441 processed. Estimated time remaining: 6583.32 sec (109.72 min)
# Processing batch 442/1061
# Batch 442 processed. Estimated time remaining: 6627.07 sec (110.45 min)
# Processing batch 443/1061
# Batch 443 processed. Estimated time remaining: 6681.24 sec (111.35 min)
# Processing batch 444/1061
# Batch 444 processed. Estimated time remaining: 6458.69 sec (107.64 min)
# Processing batch 445/1061
# Batch 445 processed. Estimated time remaining: 6606.17 sec (110.10 min)
# Processing batch 446/1061
# Batch 446 processed. Estimated time remaining: 6493.29 sec (108.22 min)
# Processing batch 447/1061
# Batch 447 processed. Estimated time remaining: 6409.72 sec (106.83 min)
# Processing batch 448/1061
# Batch 448 processed. Estimated time remaining: 6468.81 sec (107.81 min)
# Processing batch 449/1061
# Batch 449 processed. Estimated time remaining: 6514.26 sec (108.57 min)
# Processing batch 450/1061
# Batch 450 processed. Estimated time remaining: 6436.52 sec (107.28 min)
# Processing batch 451/1061
# Batch 451 processed. Estimated time remaining: 6582.63 sec (109.71 min)
# Processing batch 452/1061
# Batch 452 processed. Estimated time remaining: 6386.83 sec (106.45 min)
# Processing batch 453/1061
# Batch 453 processed. Estimated time remaining: 6412.93 sec (106.88 min)
# Processing batch 454/1061
# Batch 454 processed. Estimated time remaining: 6576.86 sec (109.61 min)
# Processing batch 455/1061
# Batch 455 processed. Estimated time remaining: 6406.62 sec (106.78 min)
# Processing batch 456/1061
# Batch 456 processed. Estimated time remaining: 6444.69 sec (107.41 min)
# Processing batch 457/1061
# Batch 457 processed. Estimated time remaining: 6417.53 sec (106.96 min)
# Processing batch 458/1061
# Batch 458 processed. Estimated time remaining: 6380.38 sec (106.34 min)
# Processing batch 459/1061
# Batch 459 processed. Estimated time remaining: 6421.42 sec (107.02 min)
# Processing batch 460/1061
# Batch 460 processed. Estimated time remaining: 6381.20 sec (106.35 min)
# Processing batch 461/1061
# Batch 461 processed. Estimated time remaining: 6250.59 sec (104.18 min)
# Processing batch 462/1061
# Batch 462 processed. Estimated time remaining: 6399.75 sec (106.66 min)
# Processing batch 463/1061
# Batch 463 processed. Estimated time remaining: 6462.94 sec (107.72 min)
# Processing batch 464/1061
# Batch 464 processed. Estimated time remaining: 6354.10 sec (105.90 min)
# Processing batch 465/1061
# Batch 465 processed. Estimated time remaining: 6342.38 sec (105.71 min)
# Processing batch 466/1061
# Batch 466 processed. Estimated time remaining: 6378.84 sec (106.31 min)
# Processing batch 467/1061
# Batch 467 processed. Estimated time remaining: 6377.59 sec (106.29 min)
# Processing batch 468/1061
# Batch 468 processed. Estimated time remaining: 6295.00 sec (104.92 min)
# Processing batch 469/1061
# Batch 469 processed. Estimated time remaining: 6280.34 sec (104.67 min)
# Processing batch 470/1061
# Batch 470 processed. Estimated time remaining: 6227.31 sec (103.79 min)
# Processing batch 471/1061
# Batch 471 processed. Estimated time remaining: 6387.91 sec (106.47 min)
# Processing batch 472/1061
# Batch 472 processed. Estimated time remaining: 6224.51 sec (103.74 min)
# Processing batch 473/1061
# Batch 473 processed. Estimated time remaining: 6169.34 sec (102.82 min)
# Processing batch 474/1061
# Batch 474 processed. Estimated time remaining: 6339.37 sec (105.66 min)
# Processing batch 475/1061
# Batch 475 processed. Estimated time remaining: 6159.25 sec (102.65 min)
# Processing batch 476/1061
# Batch 476 processed. Estimated time remaining: 6295.94 sec (104.93 min)
# Processing batch 477/1061
# Batch 477 processed. Estimated time remaining: 6083.13 sec (101.39 min)
# Processing batch 478/1061
# Batch 478 processed. Estimated time remaining: 6234.01 sec (103.90 min)
# Processing batch 479/1061
# Batch 479 processed. Estimated time remaining: 6254.03 sec (104.23 min)
# Processing batch 480/1061
# Batch 480 processed. Estimated time remaining: 6161.29 sec (102.69 min)
# Processing batch 481/1061
# Batch 481 processed. Estimated time remaining: 6130.16 sec (102.17 min)
# Processing batch 482/1061
# Batch 482 processed. Estimated time remaining: 6147.32 sec (102.46 min)
# Processing batch 483/1061
# Batch 483 processed. Estimated time remaining: 6042.78 sec (100.71 min)
# Processing batch 484/1061
# Batch 484 processed. Estimated time remaining: 6111.72 sec (101.86 min)
# Processing batch 485/1061
# Batch 485 processed. Estimated time remaining: 6148.05 sec (102.47 min)
# Processing batch 486/1061
# Batch 486 processed. Estimated time remaining: 6047.21 sec (100.79 min)
# Processing batch 487/1061
# Batch 487 processed. Estimated time remaining: 6097.51 sec (101.63 min)
# Processing batch 488/1061
# Batch 488 processed. Estimated time remaining: 5989.04 sec (99.82 min)
# Processing batch 489/1061
# Batch 489 processed. Estimated time remaining: 6163.28 sec (102.72 min)
# Processing batch 490/1061
# Batch 490 processed. Estimated time remaining: 6108.87 sec (101.81 min)
# Processing batch 491/1061
# ...
# Processing batch 898/1061
# Batch 898 processed. Estimated time remaining: 1736.29 sec (28.94 min)
# Processing batch 899/1061
# Batch 899 processed. Estimated time remaining: 1725.83 sec (28.76 min)
# Processing batch 900/1061
# Batch 900 processed. Estimated time remaining: 1719.09 sec (28.65 min)
# Processing batch 901/1061
# Batch 901 processed. Estimated time remaining: 1676.97 sec (27.95 min)
# Processing batch 902/1061
# Batch 902 processed. Estimated time remaining: 1687.94 sec (28.13 min)
# Processing batch 903/1061
# Batch 903 processed. Estimated time remaining: 1689.41 sec (28.16 min)
# Processing batch 904/1061
# Batch 904 processed. Estimated time remaining: 1691.63 sec (28.19 min)
# Processing batch 905/1061
# Batch 905 processed. Estimated time remaining: 1657.17 sec (27.62 min)
# Processing batch 906/1061
# Batch 906 processed. Estimated time remaining: 1660.51 sec (27.68 min)
# Processing batch 907/1061
# Batch 907 processed. Estimated time remaining: 1633.58 sec (27.23 min)
# Processing batch 908/1061
# Batch 908 processed. Estimated time remaining: 1644.42 sec (27.41 min)
# Processing batch 909/1061
# Batch 909 processed. Estimated time remaining: 1607.27 sec (26.79 min)
# Processing batch 910/1061
# Batch 910 processed. Estimated time remaining: 1589.91 sec (26.50 min)
# Processing batch 911/1061
# Batch 911 processed. Estimated time remaining: 1584.31 sec (26.41 min)
# Processing batch 912/1061
# Batch 912 processed. Estimated time remaining: 1582.04 sec (26.37 min)
# Processing batch 913/1061
# Batch 913 processed. Estimated time remaining: 1552.75 sec (25.88 min)
# Processing batch 914/1061
# Batch 914 processed. Estimated time remaining: 1569.87 sec (26.16 min)
# Processing batch 915/1061
# Batch 915 processed. Estimated time remaining: 1562.20 sec (26.04 min)
# Processing batch 916/1061
# Batch 916 processed. Estimated time remaining: 1557.12 sec (25.95 min)
# Processing batch 917/1061
# Batch 917 processed. Estimated time remaining: 1536.83 sec (25.61 min)
# Processing batch 918/1061
# Batch 918 processed. Estimated time remaining: 1543.91 sec (25.73 min)
# Processing batch 919/1061
# Batch 919 processed. Estimated time remaining: 1511.08 sec (25.18 min)
# Processing batch 920/1061
# Batch 920 processed. Estimated time remaining: 1471.31 sec (24.52 min)
# Processing batch 921/1061
# Batch 921 processed. Estimated time remaining: 1484.39 sec (24.74 min)
# Processing batch 922/1061
# Batch 922 processed. Estimated time remaining: 1487.09 sec (24.78 min)
# Processing batch 923/1061
# Batch 923 processed. Estimated time remaining: 1474.39 sec (24.57 min)
# Processing batch 924/1061
# Batch 924 processed. Estimated time remaining: 1452.48 sec (24.21 min)
# Processing batch 925/1061
# Batch 925 processed. Estimated time remaining: 1443.30 sec (24.06 min)
# Processing batch 926/1061
# Batch 926 processed. Estimated time remaining: 1440.59 sec (24.01 min)
# Processing batch 927/1061
# Batch 927 processed. Estimated time remaining: 1385.88 sec (23.10 min)
# Processing batch 928/1061
# Batch 928 processed. Estimated time remaining: 1408.25 sec (23.47 min)
# Processing batch 929/1061
# Batch 929 processed. Estimated time remaining: 1399.29 sec (23.32 min)
# Processing batch 930/1061
# Batch 930 processed. Estimated time remaining: 1420.55 sec (23.68 min)
# Processing batch 931/1061
# Batch 931 processed. Estimated time remaining: 1390.33 sec (23.17 min)
# Processing batch 932/1061
# Batch 932 processed. Estimated time remaining: 1368.53 sec (22.81 min)
# Processing batch 933/1061
# Batch 933 processed. Estimated time remaining: 1360.14 sec (22.67 min)
# Processing batch 934/1061
# Batch 934 processed. Estimated time remaining: 1316.06 sec (21.93 min)
# Processing batch 935/1061
# Batch 935 processed. Estimated time remaining: 1355.72 sec (22.60 min)
# Processing batch 936/1061
# Batch 936 processed. Estimated time remaining: 1330.13 sec (22.17 min)
# Processing batch 937/1061
# Batch 937 processed. Estimated time remaining: 1306.43 sec (21.77 min)
# Processing batch 938/1061
# Batch 938 processed. Estimated time remaining: 1321.89 sec (22.03 min)
# Processing batch 939/1061
# Batch 939 processed. Estimated time remaining: 1295.43 sec (21.59 min)
# Processing batch 940/1061
# Batch 940 processed. Estimated time remaining: 1290.98 sec (21.52 min)
# Processing batch 941/1061
# Batch 941 processed. Estimated time remaining: 1262.19 sec (21.04 min)
# Processing batch 942/1061
# Batch 942 processed. Estimated time remaining: 1258.69 sec (20.98 min)
# Processing batch 943/1061
# Batch 943 processed. Estimated time remaining: 1253.36 sec (20.89 min)
# Processing batch 944/1061
# Batch 944 processed. Estimated time remaining: 1255.64 sec (20.93 min)
# Processing batch 945/1061
# Batch 945 processed. Estimated time remaining: 1223.89 sec (20.40 min)
# Processing batch 946/1061
# Batch 946 processed. Estimated time remaining: 1228.67 sec (20.48 min)
# Processing batch 947/1061
# Batch 947 processed. Estimated time remaining: 1234.82 sec (20.58 min)
# Processing batch 948/1061
# Batch 948 processed. Estimated time remaining: 1181.64 sec (19.69 min)
# Processing batch 949/1061
# Batch 949 processed. Estimated time remaining: 1195.96 sec (19.93 min)
# Processing batch 950/1061
# Batch 950 processed. Estimated time remaining: 1165.60 sec (19.43 min)
# Processing batch 951/1061
# Batch 951 processed. Estimated time remaining: 1178.14 sec (19.64 min)
# Processing batch 952/1061
# Batch 952 processed. Estimated time remaining: 1169.33 sec (19.49 min)
# Processing batch 953/1061
# Batch 953 processed. Estimated time remaining: 1146.58 sec (19.11 min)
# Processing batch 954/1061
# Batch 954 processed. Estimated time remaining: 1143.51 sec (19.06 min)
# Processing batch 955/1061
# Batch 955 processed. Estimated time remaining: 1129.76 sec (18.83 min)
# Processing batch 956/1061
# Batch 956 processed. Estimated time remaining: 1105.13 sec (18.42 min)
# Processing batch 957/1061
# Batch 957 processed. Estimated time remaining: 1107.81 sec (18.46 min)
# Processing batch 958/1061
# Batch 958 processed. Estimated time remaining: 1095.29 sec (18.25 min)
# Processing batch 959/1061
# Batch 959 processed. Estimated time remaining: 1097.71 sec (18.30 min)
# Processing batch 960/1061
# Batch 960 processed. Estimated time remaining: 1064.79 sec (17.75 min)
# Processing batch 961/1061
# Batch 961 processed. Estimated time remaining: 1065.67 sec (17.76 min)
# Processing batch 962/1061
# Batch 962 processed. Estimated time remaining: 1051.77 sec (17.53 min)
# Processing batch 963/1061
# Batch 963 processed. Estimated time remaining: 1031.05 sec (17.18 min)
# Processing batch 964/1061
# Batch 964 processed. Estimated time remaining: 1027.25 sec (17.12 min)
# Processing batch 965/1061
# Batch 965 processed. Estimated time remaining: 1022.78 sec (17.05 min)
# Processing batch 966/1061
# Batch 966 processed. Estimated time remaining: 1008.98 sec (16.82 min)
# Processing batch 967/1061
# Batch 967 processed. Estimated time remaining: 1011.20 sec (16.85 min)
# Processing batch 968/1061
# Batch 968 processed. Estimated time remaining: 976.56 sec (16.28 min)
# Processing batch 969/1061
# Batch 969 processed. Estimated time remaining: 984.66 sec (16.41 min)
# Processing batch 970/1061
# Batch 970 processed. Estimated time remaining: 975.77 sec (16.26 min)
# Processing batch 971/1061
# Batch 971 processed. Estimated time remaining: 954.94 sec (15.92 min)
# Processing batch 972/1061
# Batch 972 processed. Estimated time remaining: 945.67 sec (15.76 min)
# Processing batch 973/1061
# Batch 973 processed. Estimated time remaining: 945.89 sec (15.76 min)
# Processing batch 974/1061
# Batch 974 processed. Estimated time remaining: 933.66 sec (15.56 min)
# Processing batch 975/1061
# Batch 975 processed. Estimated time remaining: 914.95 sec (15.25 min)
# Processing batch 976/1061
# Batch 976 processed. Estimated time remaining: 904.29 sec (15.07 min)
# Processing batch 977/1061
# Batch 977 processed. Estimated time remaining: 880.29 sec (14.67 min)
# Processing batch 978/1061
# Batch 978 processed. Estimated time remaining: 880.18 sec (14.67 min)
# Processing batch 979/1061
# Batch 979 processed. Estimated time remaining: 874.89 sec (14.58 min)
# Processing batch 980/1061
# Batch 980 processed. Estimated time remaining: 877.68 sec (14.63 min)
# Processing batch 981/1061
# Batch 981 processed. Estimated time remaining: 861.72 sec (14.36 min)
# Processing batch 982/1061
# Batch 982 processed. Estimated time remaining: 833.06 sec (13.88 min)
# Processing batch 983/1061
# Batch 983 processed. Estimated time remaining: 822.36 sec (13.71 min)
# Processing batch 984/1061
# Batch 984 processed. Estimated time remaining: 819.98 sec (13.67 min)
# Processing batch 985/1061
# Batch 985 processed. Estimated time remaining: 801.61 sec (13.36 min)
# Processing batch 986/1061
# Batch 986 processed. Estimated time remaining: 790.30 sec (13.17 min)
# Processing batch 987/1061
# Batch 987 processed. Estimated time remaining: 780.08 sec (13.00 min)
# Processing batch 988/1061
# Batch 988 processed. Estimated time remaining: 763.00 sec (12.72 min)
# Processing batch 989/1061
# Batch 989 processed. Estimated time remaining: 769.09 sec (12.82 min)
# Processing batch 990/1061
# Batch 990 processed. Estimated time remaining: 767.74 sec (12.80 min)
# Processing batch 991/1061
# Batch 991 processed. Estimated time remaining: 742.59 sec (12.38 min)
# Processing batch 992/1061
# Batch 992 processed. Estimated time remaining: 739.10 sec (12.32 min)
# Processing batch 993/1061
# Batch 993 processed. Estimated time remaining: 706.36 sec (11.77 min)
# Processing batch 994/1061
# Batch 994 processed. Estimated time remaining: 711.68 sec (11.86 min)
# Processing batch 995/1061
# Batch 995 processed. Estimated time remaining: 701.23 sec (11.69 min)
# Processing batch 996/1061
# Batch 996 processed. Estimated time remaining: 693.01 sec (11.55 min)
# Processing batch 997/1061
# Batch 997 processed. Estimated time remaining: 679.91 sec (11.33 min)
# Processing batch 998/1061
# Batch 998 processed. Estimated time remaining: 669.07 sec (11.15 min)
# Processing batch 999/1061
# Batch 999 processed. Estimated time remaining: 661.47 sec (11.02 min)
# Processing batch 1000/1061
# Batch 1000 processed. Estimated time remaining: 651.88 sec (10.86 min)
# Processing batch 1001/1061
# Batch 1001 processed. Estimated time remaining: 646.03 sec (10.77 min)
# Processing batch 1002/1061
# Batch 1002 processed. Estimated time remaining: 629.07 sec (10.48 min)
# Processing batch 1003/1061
# Batch 1003 processed. Estimated time remaining: 619.54 sec (10.33 min)
# Processing batch 1004/1061
# Batch 1004 processed. Estimated time remaining: 612.79 sec (10.21 min)
# Processing batch 1005/1061
# Batch 1005 processed. Estimated time remaining: 604.33 sec (10.07 min)
# Processing batch 1006/1061
# Batch 1006 processed. Estimated time remaining: 582.69 sec (9.71 min)
# Processing batch 1007/1061
# Batch 1007 processed. Estimated time remaining: 569.45 sec (9.49 min)
# Processing batch 1008/1061
# Batch 1008 processed. Estimated time remaining: 564.74 sec (9.41 min)
# Processing batch 1009/1061
# Batch 1009 processed. Estimated time remaining: 557.96 sec (9.30 min)
# Processing batch 1010/1061
# Batch 1010 processed. Estimated time remaining: 542.72 sec (9.05 min)
# Processing batch 1011/1061
# Batch 1011 processed. Estimated time remaining: 528.66 sec (8.81 min)
# Processing batch 1012/1061
# Batch 1012 processed. Estimated time remaining: 526.04 sec (8.77 min)
# Processing batch 1013/1061
# Batch 1013 processed. Estimated time remaining: 505.77 sec (8.43 min)
# Processing batch 1014/1061
# Batch 1014 processed. Estimated time remaining: 501.97 sec (8.37 min)
# Processing batch 1015/1061
# Batch 1015 processed. Estimated time remaining: 492.67 sec (8.21 min)
# Processing batch 1016/1061
# Batch 1016 processed. Estimated time remaining: 461.68 sec (7.69 min)
# Processing batch 1017/1061
# Batch 1017 processed. Estimated time remaining: 469.73 sec (7.83 min)
# Processing batch 1018/1061
# Batch 1018 processed. Estimated time remaining: 459.66 sec (7.66 min)
# Processing batch 1019/1061
# Batch 1019 processed. Estimated time remaining: 444.36 sec (7.41 min)
# Processing batch 1020/1061
# Batch 1020 processed. Estimated time remaining: 438.73 sec (7.31 min)
# Processing batch 1021/1061
# Batch 1021 processed. Estimated time remaining: 424.26 sec (7.07 min)
# Processing batch 1022/1061
# Batch 1022 processed. Estimated time remaining: 426.30 sec (7.10 min)
# Processing batch 1023/1061
# Batch 1023 processed. Estimated time remaining: 403.99 sec (6.73 min)
# Processing batch 1024/1061
# Batch 1024 processed. Estimated time remaining: 393.75 sec (6.56 min)
# Processing batch 1025/1061
# Batch 1025 processed. Estimated time remaining: 386.06 sec (6.43 min)
# Processing batch 1026/1061
# Batch 1026 processed. Estimated time remaining: 369.46 sec (6.16 min)
# Processing batch 1027/1061
# Batch 1027 processed. Estimated time remaining: 359.57 sec (5.99 min)
# Processing batch 1028/1061
# Batch 1028 processed. Estimated time remaining: 357.05 sec (5.95 min)
# Processing batch 1029/1061
# Batch 1029 processed. Estimated time remaining: 341.79 sec (5.70 min)
# Processing batch 1030/1061
# Batch 1030 processed. Estimated time remaining: 327.86 sec (5.46 min)
# Processing batch 1031/1061
# Batch 1031 processed. Estimated time remaining: 313.31 sec (5.22 min)
# Processing batch 1032/1061
# Batch 1032 processed. Estimated time remaining: 304.14 sec (5.07 min)
# Processing batch 1033/1061
# Batch 1033 processed. Estimated time remaining: 303.49 sec (5.06 min)
# Processing batch 1034/1061
# Batch 1034 processed. Estimated time remaining: 287.00 sec (4.78 min)
# Processing batch 1035/1061
# Batch 1035 processed. Estimated time remaining: 279.93 sec (4.67 min)
# Processing batch 1036/1061
# Batch 1036 processed. Estimated time remaining: 266.98 sec (4.45 min)
# Processing batch 1037/1061
# Batch 1037 processed. Estimated time remaining: 254.15 sec (4.24 min)
# Processing batch 1038/1061
# Batch 1038 processed. Estimated time remaining: 243.84 sec (4.06 min)
# Processing batch 1039/1061
# Batch 1039 processed. Estimated time remaining: 233.28 sec (3.89 min)
# Processing batch 1040/1061
# Batch 1040 processed. Estimated time remaining: 224.25 sec (3.74 min)
# Processing batch 1041/1061
# Batch 1041 processed. Estimated time remaining: 212.28 sec (3.54 min)
# Processing batch 1042/1061
# Batch 1042 processed. Estimated time remaining: 204.32 sec (3.41 min)
# Processing batch 1043/1061
# Batch 1043 processed. Estimated time remaining: 190.05 sec (3.17 min)
# Processing batch 1044/1061
# Batch 1044 processed. Estimated time remaining: 180.80 sec (3.01 min)
# Processing batch 1045/1061
# Batch 1045 processed. Estimated time remaining: 171.29 sec (2.85 min)
# Processing batch 1046/1061
# Batch 1046 processed. Estimated time remaining: 156.81 sec (2.61 min)
# Processing batch 1047/1061
# Batch 1047 processed. Estimated time remaining: 148.33 sec (2.47 min)
# Processing batch 1048/1061
# Batch 1048 processed. Estimated time remaining: 139.04 sec (2.32 min)
# Processing batch 1049/1061
# Batch 1049 processed. Estimated time remaining: 130.08 sec (2.17 min)
# Processing batch 1050/1061
# Batch 1050 processed. Estimated time remaining: 117.29 sec (1.95 min)
# Processing batch 1051/1061
# Batch 1051 processed. Estimated time remaining: 105.52 sec (1.76 min)
# Processing batch 1052/1061
# Batch 1052 processed. Estimated time remaining: 93.94 sec (1.57 min)
# Processing batch 1053/1061
# Batch 1053 processed. Estimated time remaining: 85.80 sec (1.43 min)
# Processing batch 1054/1061
# Batch 1054 processed. Estimated time remaining: 73.27 sec (1.22 min)
# Processing batch 1055/1061
# Batch 1055 processed. Estimated time remaining: 64.20 sec (1.07 min)
# Processing batch 1056/1061
# Batch 1056 processed. Estimated time remaining: 52.95 sec (0.88 min)
# Processing batch 1057/1061
# Batch 1057 processed. Estimated time remaining: 42.85 sec (0.71 min)
# Processing batch 1058/1061
# Batch 1058 processed. Estimated time remaining: 31.88 sec (0.53 min)
# Processing batch 1059/1061
# Batch 1059 processed. Estimated time remaining: 21.30 sec (0.36 min)
# Processing batch 1060/1061
# Batch 1060 processed. Estimated time remaining: 10.68 sec (0.18 min)
# Processing batch 1061/1061
# Batch 1061 processed. Estimated time remaining: 0.00 sec (0.00 min)
# CPU times: user 3h 8min 12s, sys: 8min 57s, total: 3h 17min 10s
# Wall time: 3h 7min 33s

# %% [markdown]
# На TeslaM40 модель училась 3 часа 7 минут, что очень долго..

# %%
# with open('embeddings.pickle', 'wb') as f:
#     pickle.dump(embeddings, f)
# None

# %%
with open('embeddings.pickle', 'rb') as f:
    embeddings = pickle.load(f)

# %% [markdown]
# Получаем признаки, разделяем на выборки

# %%
x = np.concatenate(embeddings)
y = data['toxic'][0:159150]

# %%
x, x_test, y, y_test = train_test_split(x, y, random_state=RANDOM_STATE, stratify=y)

# %% [markdown]
# Обучим модель классификации

# %%
model = LogisticRegression(random_state=RANDOM_STATE, n_jobs=-1)

# %%
param_grid = {
    'solver':['lbfgs', 'saga'],
    'C':[0.05, 0.1, 0.15],
    'class_weight': ['balanced'],
                  
}

gs_lr = GridSearchCV(
    model,
    param_grid,
    scoring='f1',
    n_jobs = -1,
    verbose=1
)

# %%
# %time gs_lr.fit(x, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# CPU times: user 4min 40s, sys: 44.7 s, total: 5min 25s
# Wall time: 10min 18s
# /home/cvc/anaconda3/envs/jh/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(estimator=LogisticRegression(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'C': [0.05, 0.1, 0.15], 'class_weight': ['balanced'],
#                          'solver': ['lbfgs', 'saga']},
#              scoring='f1', verbose=1)

# %%
pd.DataFrame(gs_lr.cv_results_)[
    ['param_C',
     'param_solver',
     'mean_test_score',
     'rank_test_score']
]
# Out:
#   param_C param_solver  mean_test_score  rank_test_score
# 0    0.05        lbfgs         0.922260                5
# 1    0.05         saga         0.922076                6
# 2     0.1        lbfgs         0.923242                4
# 3     0.1         saga         0.923264                3
# 4    0.15        lbfgs         0.923753                2
# 5    0.15         saga         0.924357                1

# %% [markdown]
# Получим предсказания на тестовой выборке

# %%
predictions = gs_lr.best_estimator_.predict(x_test)

cr = classification_report(y_test, predictions, output_dict=True)
display(pd.DataFrame(cr).round(decimals=3).transpose())
# Out:
#               precision  recall  f1-score    support
# 0                 0.998   0.984     0.991  35744.000
# 1                 0.871   0.986     0.925   4044.000
# accuracy          0.984   0.984     0.984      0.984
# macro avg         0.935   0.985     0.958  39788.000
# weighted avg      0.985   0.984     0.984  39788.000

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе работы был проведен анализ данных, данные подготовлены для работы с моделями LR и LGBM
#
# Модель LGBM показала относительно высокую метрику на обучающей выборке: `f1 ~ 0.77`
# Далее были составлены эмбеддинги с помощью модели BERT, затем LR, недостатком стало длительное время обучения, но при этом были получены хорошие результаты, точность предсказаний составила `f1 > 0.92`
